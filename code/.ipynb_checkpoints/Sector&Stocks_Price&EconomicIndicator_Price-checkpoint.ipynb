# %% [markdown]
# ### 코스피, 코스닥 종목 필터링

# %%
import pandas as pd
import numpy as np
import FinanceDataReader as fdr


stock_list = fdr.StockListing('KRX') # 코스피, 코스닥, 코넥스 종목 모두 불러오기
stock_list = stock_list.loc[stock_list['Market'].isin(['KOSPI', 'KOSDAQ'])]

#stock_name_list = stock_list['Name'].tolist()
stock_name_list = stock_list.loc[~(stock_list['Name'].str.endswith(('우C','우B', '우', '홀딩스', '지주', '지주회사')) | stock_list['Name'].str.contains('스팩')), :] # 우선주, 지주사, 스팩주 제외

# %% [markdown]
# ### 국내 주식 가격 가져오기

# %%
kr_sel = pd.DataFrame()
start_date = '2023-01-03'
end_date = '2023-08-30'

for ix, row in stock_name_list.iterrows():
    code, name = row['Code'], row['Name']
    print(code, name)
    # 개별 종목의 가격 가져오기(주최 측에서 제공되는 데이터의 날짜와 동일하게)
    df = fdr.DataReader(code, '2023-01-03', '2023-08-30')

    # 가격 데이터의 종가(Close)를 컬럼으로 추가
    # 컬럼명은 종목명을 지정
    kr_sel[name] = df['Close']
# Out:
# 005930 삼성전자
# 373220 LG에너지솔루션
# 000660 SK하이닉스
# 207940 삼성바이오로직스
# 005380 현대차
# 051910 LG화학
# 006400 삼성SDI
# 000270 기아
# 035420 NAVER
# 003670 포스코퓨처엠
# 105560 KB금융
# 086520 에코프로
# 012330 현대모비스
# 068270 셀트리온
# 028260 삼성물산
# 035720 카카오
# 066570 LG전자
# 096770 SK이노베이션
# 032830 삼성생명
# 003550 LG
# 000810 삼성화재
# 033780 KT&G
# 047050 포스코인터내셔널
# 034730 SK
# 015760 한국전력
# 323410 카카오뱅크
# 017670 SK텔레콤
# 018260 삼성에스디에스
# 009150 삼성전기
# 352820 하이브
# 010130 고려아연
# 329180 HD현대중공업
# 024110 기업은행
# 034020 두산에너빌리티
# 030200 KT
# 010950 S-Oil
# 259960 크래프톤
# 003490 대한항공
# 009540 HD한국조선해양
# 011200 HMM
# 001570 금양
# 010140 삼성중공업
# 090430 아모레퍼시픽
# 051900 LG생활건강
# 086280 현대글로비스
# 326030 SK바이오팜
# 402340 SK스퀘어
# 005830 DB손해보험
# 042660 한화오션
# 011170 롯데케미칼
# 000100 유한양행
# 028050 삼성엔지니어링
# 011070 LG이노텍
# 042700 한미반도체
# 377300 카카오페이
# 012450 한화에어로스페이스
# 088980 맥쿼리인프라
# 009830 한화솔루션
# 302440 SK바이오사이언스
# 241560 두산밥캣
# 271560 오리온
# 005070 코스모신소재
# 361610 SK아이이테크놀로지
# 047810 한국항공우주
# 036570 엔씨소프트
# 307950 현대오토에버
# 267250 HD현대
# 161390 한국타이어앤테크놀로지
# 004020 현대제철
# 032640 LG유플러스
# 034220 LG디스플레이
# 097950 CJ제일제당
# 018880 한온시스템
# 000720 현대건설
# 028300 HLB
# 383220 F&F
# 128940 한미약품
# 011780 금호석유
# 078930 GS
# 006800 미래에셋증권
# 251270 넷마블
# 029780 삼성카드
# 005940 NH투자증권
# 016360 삼성증권
# 035250 강원랜드
# 021240 코웨이
# 064350 현대로템
# 001450 현대해상
# 041510 에스엠
# 454910 두산로보틱스
# 010620 현대미포조선
# 006260 LS
# 011790 SKC
# 180640 한진칼
# 403870 HPSP
# 004370 농심
# 008770 호텔신라
# 003410 쌍용C&E
# 277810 레인보우로보틱스
# 039490 키움증권
# 068760 셀트리온제약
# 267260 HD현대일렉트릭
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 010120 LS ELECTRIC
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 088350 한화생명
# 007070 GS리테일
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 052690 한전기술
# 282330 BGF리테일
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 272210 한화시스템
# 008930 한미사이언스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 030000 제일기획
# 001040 CJ
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 000990 DB하이텍
# 112610 씨에스윈드
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 006110 삼아알미늄
# 002790 아모레G
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 006740 영풍제지
# 028670 팬오션
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 036460 한국가스공사
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 111770 영원무역
# 012750 에스원
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 002380 KCC
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 023530 롯데쇼핑
# 139480 이마트
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 079550 LIG넥스원
# 328130 루닛
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 014680 한솔케미칼
# 042670 HD현대인프라코어
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 009420 한올바이오파마
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 020150 롯데에너지머티리얼즈
# 000250 삼천당제약
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 007660 이수페타시스
# 357780 솔브레인
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 002710 TCC스틸
# 026960 동서
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 000880 한화
# 017800 현대엘리베이
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 000120 CJ대한통운
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 004170 신세계
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 204320 HL만도
# 005290 동진쎄미켐
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 393890 더블유씨피
# 440110 파두
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 011210 현대위아
# 298050 효성첨단소재
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 047040 대우건설
# 121600 나노신소재
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 003620 KG모빌리티
# 214370 케어젠
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 298040 효성중공업
# 086900 메디톡스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 065350 신성델타테크
# 051600 한전KPS
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 025900 동화기업
# 004000 롯데정밀화학
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 095340 ISC
# 248070 솔루엠
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 001440 대한전선
# 007310 오뚜기
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 018670 SK가스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 003230 삼양식품
# 000150 두산
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 001740 SK네트웍스
# 253450 스튜디오드래곤
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 005850 에스엘
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 005420 코스모화학
# 006040 동원산업
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 000080 하이트진로
# 192820 코스맥스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 372170 윤성에프앤씨
# 034230 파라다이스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 069620 대웅제약
# 137310 에스디바이오센서
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 298020 효성티앤씨
# 069960 현대백화점
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 108320 LX세미콘
# 078600 대주전자재료
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 120110 코오롱인더
# 365340 성일하이텍
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 185750 종근당
# 353200 대덕전자
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 005300 롯데칠성
# 073240 금호타이어
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 267270 HD현대건설기계
# 004800 효성
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 006280 녹십자
# 222800 심텍
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 003690 코리안리
# 112040 위메이드
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 009240 한샘
# 336260 두산퓨얼셀
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 009520 포스코엠텍
# 375500 DL이앤씨
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 016790 카나리아바이오
# 145720 덴티움
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 161890 한국콜마
# 006360 GS건설
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 122870 와이지엔터테인먼트
# 140860 파크시스템스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 140410 메지온
# 048410 현대바이오
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 096530 씨젠
# 383310 에코프로에이치엔
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 285130 SK케미칼
# 000240 한국앤컴퍼니
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 280360 롯데웰푸드
# 100090 SK오션플랜트
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 039200 오스코텍
# 085660 차바이오텍
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 001120 LX인터내셔널
# 225570 넥슨게임즈
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 457190 이수스페셜티케미컬
# 093370 후성
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 003090 대웅
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 103140 풍산
# 089860 롯데렌탈
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 067630 HLB생명과학
# 195870 해성디에스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 000670 영풍
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# ...
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 377460 위니아에이드
# 208860 엔지스테크널러지
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 043360 디지아이
# 114120 크루셜텍
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 072520 제넨바이오
# 123330 제닉
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 026910 광진실업
# 009310 참엔지니어링
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 073540 에프알텍
# 011080 형지I&C
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 039740 한국정보공학
# 227100 에이치앤비디자인
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 023790 동일철강
# 062970 피피아이
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 091440 텔레필드
# 054630 에이디칩스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 214310 에스엘에너지
# 054180 메디콕스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 067770 세진티에스
# 101680 한국정밀기계
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 900270 헝셩그룹
# 096870 엘디티
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 065690 파커스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 070300 엑스큐어
# 321820 와이더플래닛
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 033790 스카이문스테크놀로지
# 030790 비케이탑스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 078860 아이오케이
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 069140 누리플랜
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 044180 KD
# 071950 코아스
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 046070 코다코
# 008500 일정실업
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 140910 에이리츠
# 106520 노블엠앤비
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 217480 에스디생명공학
# 174880 장원테크
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# 058220 아리온
# 121890 에스디시스템
# 069110 코스온
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\2934279478.py:13: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel[name] = df['Close']

# %%
kr_sel['Date'] = kr_sel.index
kr_sel.reset_index(drop = True, inplace = True)
kr_sel['Date'] = kr_sel['Date'].astype(str)

col1 = kr_sel.columns[-1:].to_list()
col2 = kr_sel.columns[:-1].to_list()
new_col = col1 + col2
kr_sel = kr_sel[new_col]
kr_sel
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_13288\3565712720.py:1: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   kr_sel['Date'] = kr_sel.index
#            Date   삼성전자  LG에너지솔루션  SK하이닉스  삼성바이오로직스     현대차    LG화학   삼성SDI  \
# 0    2023-01-03  55400    440500   75600    803000  159000  601000  605000
# 1    2023-01-04  57800    443000   81000    794000  160500  601000  603000
# 2    2023-01-05  58200    433500   81400    808000  159000  581000  583000
# 3    2023-01-06  59000    444000   83100    808000  159500  594000  586000
# 4    2023-01-09  60700    464000   86000    812000  164000  624000  600000
# ..          ...    ...       ...     ...       ...     ...     ...     ...
# 159  2023-08-24  68200    535000  120900    763000  186400  563000  594000
# 160  2023-08-25  67100    546000  116500    757000  186200  560000  595000
# 161  2023-08-28  66800    553000  115900    750000  185400  563000  599000
# 162  2023-08-29  66800    552000  118600    753000  186700  560000  596000
# 163  2023-08-30  67100    553000  119400    755000  187800  576000  606000
#
#         기아   NAVER  ...  코아스   코다코   일정실업  에이리츠  노블엠앤비  에스디생명공학  장원테크  아리온  \
# 0    62400  178500  ...  700  1000  16350  3990   2505     1255   747  275
# 1    62000  182500  ...  706   997  16200  4035   2415     1245   721  275
# 2    61100  186000  ...  710  1010  16200  4085   2210     1235   754  275
# 3    61500  185000  ...  710  1050  15950  4085   2195     1160   737  275
# 4    64100  196500  ...  722  1070  16000  4100   2220     1320   790  275
# ..     ...     ...  ...  ...   ...    ...   ...    ...      ...   ...  ...
# 159  78800  229000  ...  655   522  12900  3745    411      349   530  275
# 160  78100  211000  ...  652   521  12900  3650    411      349   530  275
# 161  78300  213500  ...  661   407  12900  3700    411      349   530  275
# 162  80200  218000  ...  672   432  12900  3715    411      349   530  275
# 163  80400  217500  ...  672   561  12900  3745    411      349   530  275
#
#      에스디시스템   코스온
# 0       739  2630
# 1       739  2630
# 2       739  2630
# 3       739  2630
# 4       739  2630
# ..      ...   ...
# 159     739  2630
# 160     739  2630
# 161     739  2630
# 162     739  2630
# 163     739  2630
#
# [164 rows x 2298 columns]

# %%
# 국내, 해외, 경제지표 날짜 맞추기 위함
Date = pd.date_range(start="2023-01-03", end="2023-08-30").astype(str)
D = pd.DataFrame()

D['Date'] = Date
D
# Out:
#            Date
# 0    2023-01-03
# 1    2023-01-04
# 2    2023-01-05
# 3    2023-01-06
# 4    2023-01-07
# ..          ...
# 235  2023-08-26
# 236  2023-08-27
# 237  2023-08-28
# 238  2023-08-29
# 239  2023-08-30
#
# [240 rows x 1 columns]

# %%
kr_price = pd.merge(D, kr_sel, how='left', on='Date')
kr_price = kr_price.fillna(method = 'pad') #결측치 바로 이전 행값으로 채우기
kr_price
# Out:
#            Date     삼성전자  LG에너지솔루션    SK하이닉스  삼성바이오로직스       현대차      LG화학  \
# 0    2023-01-03  55400.0  440500.0   75600.0  803000.0  159000.0  601000.0
# 1    2023-01-04  57800.0  443000.0   81000.0  794000.0  160500.0  601000.0
# 2    2023-01-05  58200.0  433500.0   81400.0  808000.0  159000.0  581000.0
# 3    2023-01-06  59000.0  444000.0   83100.0  808000.0  159500.0  594000.0
# 4    2023-01-07  59000.0  444000.0   83100.0  808000.0  159500.0  594000.0
# ..          ...      ...       ...       ...       ...       ...       ...
# 235  2023-08-26  67100.0  546000.0  116500.0  757000.0  186200.0  560000.0
# 236  2023-08-27  67100.0  546000.0  116500.0  757000.0  186200.0  560000.0
# 237  2023-08-28  66800.0  553000.0  115900.0  750000.0  185400.0  563000.0
# 238  2023-08-29  66800.0  552000.0  118600.0  753000.0  186700.0  560000.0
# 239  2023-08-30  67100.0  553000.0  119400.0  755000.0  187800.0  576000.0
#
#         삼성SDI       기아     NAVER  ...    코아스     코다코     일정실업    에이리츠   노블엠앤비  \
# 0    605000.0  62400.0  178500.0  ...  700.0  1000.0  16350.0  3990.0  2505.0
# 1    603000.0  62000.0  182500.0  ...  706.0   997.0  16200.0  4035.0  2415.0
# 2    583000.0  61100.0  186000.0  ...  710.0  1010.0  16200.0  4085.0  2210.0
# 3    586000.0  61500.0  185000.0  ...  710.0  1050.0  15950.0  4085.0  2195.0
# 4    586000.0  61500.0  185000.0  ...  710.0  1050.0  15950.0  4085.0  2195.0
# ..        ...      ...       ...  ...    ...     ...      ...     ...     ...
# 235  595000.0  78100.0  211000.0  ...  652.0   521.0  12900.0  3650.0   411.0
# 236  595000.0  78100.0  211000.0  ...  652.0   521.0  12900.0  3650.0   411.0
# 237  599000.0  78300.0  213500.0  ...  661.0   407.0  12900.0  3700.0   411.0
# 238  596000.0  80200.0  218000.0  ...  672.0   432.0  12900.0  3715.0   411.0
# 239  606000.0  80400.0  217500.0  ...  672.0   561.0  12900.0  3745.0   411.0
#
#      에스디생명공학   장원테크    아리온  에스디시스템     코스온
# 0     1255.0  747.0  275.0   739.0  2630.0
# 1     1245.0  721.0  275.0   739.0  2630.0
# 2     1235.0  754.0  275.0   739.0  2630.0
# 3     1160.0  737.0  275.0   739.0  2630.0
# 4     1160.0  737.0  275.0   739.0  2630.0
# ..       ...    ...    ...     ...     ...
# 235    349.0  530.0  275.0   739.0  2630.0
# 236    349.0  530.0  275.0   739.0  2630.0
# 237    349.0  530.0  275.0   739.0  2630.0
# 238    349.0  530.0  275.0   739.0  2630.0
# 239    349.0  530.0  275.0   739.0  2630.0
#
# [240 rows x 2298 columns]

# %% [markdown]
# ### 해외 주식 가격 및 Sector 분류

# %%
# yahoo finance, GICS 체계 활용해서 분류된 raw 데이터 및 제공되는 데이터에 merge한 거
kr = pd.read_csv('C:/Users/Administrator/Desktop/비어플_NH/data/korea_sector.csv')
ov = pd.read_csv('C:/Users/Administrator/Desktop/비어플_NH/data/overseas_sector.csv')

# %%
kr
# Out:
#       Unnamed: 0    종목코드     종목명    시장구분    소속부     종가   대비   등락률     시가  \
# 0              0  060310      3S  KOSDAQ  중견기업부   2210  -80 -3.49   2275
# 1              1  095570  AJ네트웍스   KOSPI    NaN   4100  -55 -1.32   4125
# 2              2  006840   AK홀딩스   KOSPI    NaN  18430  -60 -0.32  18550
# 3              3  054620     APS  KOSDAQ  중견기업부   7600 -210 -2.69   7760
# 4              4  265520   AP시스템  KOSDAQ  우량기업부  17050  -50 -0.29  17050
# ...          ...     ...     ...     ...    ...    ...  ...   ...    ...
# 2748        2748  000540    흥국화재   KOSPI    NaN   2995  -95 -3.07   3100
# 2749        2749  000545   흥국화재우   KOSPI    NaN   5030   10  0.20   5090
# 2750        2750  003280    흥아해운   KOSPI    NaN   1612  -31 -1.89   1631
# 2751        2751  037440      희림  KOSDAQ  우량기업부   9060  480  5.59   8640
# 2752        2752  238490      힘스  KOSDAQ  벤처기업부   6040  -10 -0.17   6050
#
#          고가     저가      거래량        거래대금          시가총액      상장주식수    업종명 sector
# 0      2300   2190   548987  1226832035  107265978820   48536642  기계·장비    산업재
# 1      4195   4080   178784   736372865  191971409500   46822295   서비스업    산업재
# 2     18880  17990     7484   136046950  244152549230   13247561   기타금융     금융
# 3      7970   7560    29708   229077360  154996079600   20394221     금융     금융
# 4     17380  16960    30925   527443450  260548228050   15281421    반도체   정보기술
# ...     ...    ...      ...         ...           ...        ...    ...    ...
# 2748   3100   2995    45341   137437410  192406721775   64242645     보험     금융
# 2749   5090   5020      238     1197300    3863040000     768000     보험     금융
# 2750   1658   1602   320208   518396197  387564937188  240424899  운수창고업    산업재
# 2751   9060   8400  1057106  9236586150  126137623500   13922475  기타서비스    산업재
# 2752   6090   6000    13082    78811060   68325905440   11312236    반도체   정보기술
#
# [2753 rows x 17 columns]

# %%
ov
# Out:
#         Unnamed: 0    trd_dt tck_iem_cd  gts_iem_ong_pr  gts_iem_hi_pr  \
# 0                0  20230103       NVDA        148.5100       149.9600
# 1                1  20230103       APLT          0.7535         0.7900
# 2                2  20230103        ANY          1.8900         2.0293
# 3                3  20230103       CLRB          1.6600         1.7200
# 4                4  20230103      NYMTM         18.4300        18.7400
# ...            ...       ...        ...             ...            ...
# 455333      455333  20230830       BLZE          5.9900         6.1290
# 455334      455334  20230830       ELDN          1.4800         1.5794
# 455335      455335  20230830       BMBL         15.9000        16.4400
# 455336      455336  20230830       PLRX         16.7900        16.7900
# 455337      455337  20230830       CNDT          3.2100         3.2400
#
#         gts_iem_low_pr  gts_iem_end_pr  gts_acl_trd_qty  gts_sll_cns_sum_qty  \
# 0             140.9600        143.1500       40127658.0                  0.0
# 1               0.7308          0.7522          63714.0              19658.0
# 2               1.8354          1.9600          24896.4                  0.0
# 3               1.6300          1.6300          21212.0              16444.0
# 4              18.4300         18.7000           8061.0                  0.0
# ...                ...             ...              ...                  ...
# 455333          5.8300          5.8600         443470.0             205162.0
# 455334          1.4100          1.4900          13462.0               5492.0
# 455335         15.7900         16.3200        1030250.0             576506.0
# 455336         16.2250         16.7100         319531.0             138554.0
# 455337          3.1000          3.1100         617367.0             320503.0
#
#         gts_byn_cns_sum_qty  isin_cd  fc_sec_krl_nm  fc_sec_eng_nm  \
# 0                       0.0      NaN            NaN            NaN
# 1                   44056.0      NaN            NaN            NaN
# 2                       0.0      NaN            NaN            NaN
# 3                    4768.0      NaN            NaN            NaN
# 4                       0.0      NaN            NaN            NaN
# ...                     ...      ...            ...            ...
# 455333             238308.0      NaN            NaN            NaN
# 455334               7970.0      NaN            NaN            NaN
# 455335             453744.0      NaN            NaN            NaN
# 455336             180977.0      NaN            NaN            NaN
# 455337             296864.0      NaN            NaN            NaN
#
#              Sector
# 0        Technology
# 1        Healthcare
# 2        Technology
# 3        Healthcare
# 4       Real Estate
# ...             ...
# 455333   Technology
# 455334   Healthcare
# 455335   Technology
# 455336   Healthcare
# 455337   Technology
#
# [455338 rows x 14 columns]

# %%
# 날짜 형식 다른 데이터랑 맞추기 위해 processing
ov['trd_dt'] = ov['trd_dt'].astype(str)
ov['trd_dt'] = pd.to_datetime(ov['trd_dt']).astype(str)

ov_sel = ov.loc[:,['trd_dt','tck_iem_cd','gts_iem_end_pr']]
ov_sel.columns = ['Date','종목명','Close']

ov_sel = pd.pivot_table(ov_sel, index = 'Date',columns = '종목명',values = 'Close')

ov_sel['Date'] = ov_sel.index
ov_sel.reset_index(drop = True, inplace = True)

col1 = ov_sel.columns[-1:].to_list()
col2 = ov_sel.columns[:-1].to_list()
new_col = col1 + col2
ov_sel = ov_sel[new_col]
ov_sel
# Out:
# 종목명        Date    AACG   AADI    AAL   AAOI     AAON    AAPL   ABCB  ABCL  \
# 0    2023-01-03  1.2600  12.31  12.74   1.88  49.8867  125.07  46.30  9.49
# 1    2023-01-04  1.2700  12.67  13.59   1.92  47.7800  126.36  46.49  9.37
# 2    2023-01-05  1.3210  12.52  13.99   1.88  47.0000  125.02  46.01  9.65
# 3    2023-01-06  1.4123  12.49  14.18   1.86  49.4600  129.62  47.47  9.51
# 4    2023-01-09  1.4000  12.13  14.61   2.15  49.6067  130.15  47.35  9.55
# ..          ...     ...    ...    ...    ...      ...     ...    ...   ...
# 161  2023-08-24  1.2100   6.61  14.57  14.09  60.0000  176.38  39.69  5.50
# 162  2023-08-25  1.2300   7.13  14.58  12.99  60.7000  178.61  39.44  5.51
# 163  2023-08-28  1.2100   6.80  14.73  12.97  60.7800  180.19  39.97  5.50
# 164  2023-08-29  1.2400   6.71  14.90  14.10  62.7600  184.12  40.26  5.66
# 165  2023-08-30  1.2600   6.68  14.77  15.22  62.7800  187.65  40.06  5.80
#
# 종목명   ABCM  ...     ZM   ZNTL      ZS    ZTEK    ZUMZ  ZVRA    ZVSA  ZYME  \
# 0    15.61  ...  66.66  20.65  110.19  1.5499  22.010  4.53  1.7300  7.54
# 1    17.00  ...  67.65  21.04  111.59  1.5321  22.575  4.73  1.5501  7.67
# 2    16.78  ...  65.62  21.27  104.39  1.5000  22.370  4.48  1.6200  8.00
# 3    15.92  ...  69.51  21.21  103.96  1.4800  23.310  4.57  1.6100  7.65
# 4    16.39  ...  70.08  18.53  104.75  1.4450  23.540  4.54  2.4611  7.54
# ..     ...  ...    ...    ...     ...     ...     ...   ...     ...   ...
# 161  22.49  ...  66.95  25.22  139.74  1.4000  18.100  4.92  0.1510  7.66
# 162  23.36  ...  67.70  25.59  142.76  1.4100  18.050  4.97  0.1486  7.70
# 163  22.35  ...  67.57  25.62  141.34  1.3999  17.660  5.11  0.1490  7.49
# 164  22.67  ...  68.81  25.59  144.39  1.4000  18.280  5.31  0.1426  7.53
# 165  22.60  ...  68.67  26.58  147.28  1.4199  18.150  5.30  0.1423  7.35
#
# 종목명    ZYNE   ZYXI
# 0    0.5491  13.88
# 1    0.5582  14.11
# 2    0.5400  14.14
# 3    0.5420  15.65
# 4    0.5400  15.65
# ..      ...    ...
# 161  1.3200   7.75
# 162  1.3250   7.70
# 163  1.3200   7.66
# 164  1.3200   7.71
# 165  1.3200   7.75
#
# [166 rows x 2744 columns]

# %%
# 국내, 해외, 경제지표 날짜 맞추기 위함
#Date = pd.date_range(start="2023-01-03", end="2023-08-30").astype(str)
#D = pd.DataFrame()

#D['Date'] = Date
#D

# %%
ov_price = pd.merge(D, ov_sel, how='left', on='Date')
ov_price = ov_price.fillna(method = 'pad') #결측치 바로 이전 행값으로 채우기
ov_price
# Out:
#            Date    AACG   AADI    AAL   AAOI     AAON    AAPL   ABCB  ABCL  \
# 0    2023-01-03  1.2600  12.31  12.74   1.88  49.8867  125.07  46.30  9.49
# 1    2023-01-04  1.2700  12.67  13.59   1.92  47.7800  126.36  46.49  9.37
# 2    2023-01-05  1.3210  12.52  13.99   1.88  47.0000  125.02  46.01  9.65
# 3    2023-01-06  1.4123  12.49  14.18   1.86  49.4600  129.62  47.47  9.51
# 4    2023-01-07  1.4123  12.49  14.18   1.86  49.4600  129.62  47.47  9.51
# ..          ...     ...    ...    ...    ...      ...     ...    ...   ...
# 235  2023-08-26  1.2300   7.13  14.58  12.99  60.7000  178.61  39.44  5.51
# 236  2023-08-27  1.2300   7.13  14.58  12.99  60.7000  178.61  39.44  5.51
# 237  2023-08-28  1.2100   6.80  14.73  12.97  60.7800  180.19  39.97  5.50
# 238  2023-08-29  1.2400   6.71  14.90  14.10  62.7600  184.12  40.26  5.66
# 239  2023-08-30  1.2600   6.68  14.77  15.22  62.7800  187.65  40.06  5.80
#
#       ABCM  ...     ZM   ZNTL      ZS    ZTEK    ZUMZ  ZVRA    ZVSA  ZYME  \
# 0    15.61  ...  66.66  20.65  110.19  1.5499  22.010  4.53  1.7300  7.54
# 1    17.00  ...  67.65  21.04  111.59  1.5321  22.575  4.73  1.5501  7.67
# 2    16.78  ...  65.62  21.27  104.39  1.5000  22.370  4.48  1.6200  8.00
# 3    15.92  ...  69.51  21.21  103.96  1.4800  23.310  4.57  1.6100  7.65
# 4    15.92  ...  69.51  21.21  103.96  1.4800  23.310  4.57  1.6100  7.65
# ..     ...  ...    ...    ...     ...     ...     ...   ...     ...   ...
# 235  23.36  ...  67.70  25.59  142.76  1.4100  18.050  4.97  0.1486  7.70
# 236  23.36  ...  67.70  25.59  142.76  1.4100  18.050  4.97  0.1486  7.70
# 237  22.35  ...  67.57  25.62  141.34  1.3999  17.660  5.11  0.1490  7.49
# 238  22.67  ...  68.81  25.59  144.39  1.4000  18.280  5.31  0.1426  7.53
# 239  22.60  ...  68.67  26.58  147.28  1.4199  18.150  5.30  0.1423  7.35
#
#        ZYNE   ZYXI
# 0    0.5491  13.88
# 1    0.5582  14.11
# 2    0.5400  14.14
# 3    0.5420  15.65
# 4    0.5420  15.65
# ..      ...    ...
# 235  1.3250   7.70
# 236  1.3250   7.70
# 237  1.3200   7.66
# 238  1.3200   7.71
# 239  1.3200   7.75
#
# [240 rows x 2744 columns]

# %% [markdown]
# # Sector 분류

# %%
kr_sec = kr.loc[:,['종목명','sector']]
ov_sec = ov.loc[:,['tck_iem_cd','Sector']]
ov_sec.drop_duplicates(ignore_index = True, inplace=True)
ov_sec.columns = ['종목명','sector_en']

# %%
sec = {'Consumer_cyclical': '자유소비재',
                          'Basic Materials': '소재',
                          'Consumer Defensive': '필수소비재',
                          'Technology': '정보기술',
                          'Communication Services': '커뮤니케이션서비스',
                          'Financial Services': '금융',
                          'Utilities': '유틸리티',
                          'Industrials': '산업재',
                          'Energy': '에너지',
                          'Healthcare': '헬스케어'}

ov_sec['sector'] = ov_sec['sector_en'].map(sec)

# %%
kr_sec['sector'].value_counts()
# Out:
# sector
# 산업재          630
# 정보기술         619
# 소재           417
# 금융           262
# 헬스케어         254
# 자유소비재        242
# 커뮤니케이션서비스     96
# 필수소비재         93
# 유틸리티          12
# Name: count, dtype: int64

# %%
ov_sec['sector'].value_counts()
# Out:
# sector
# 헬스케어         953
# 정보기술         469
# 금융           365
# 산업재          246
# 커뮤니케이션서비스    160
# 필수소비재        102
# 소재            52
# 에너지           40
# 유틸리티          26
# Name: count, dtype: int64

# %%
kr_sec
# Out:
#          종목명 sector
# 0         3S    산업재
# 1     AJ네트웍스    산업재
# 2      AK홀딩스     금융
# 3        APS     금융
# 4      AP시스템   정보기술
# ...      ...    ...
# 2748    흥국화재     금융
# 2749   흥국화재우     금융
# 2750    흥아해운    산업재
# 2751      희림    산업재
# 2752      힘스   정보기술
#
# [2753 rows x 2 columns]

# %%
ov_sec
# Out:
#         종목명           sector_en sector
# 0      NVDA          Technology   정보기술
# 1      APLT          Healthcare   헬스케어
# 2       ANY          Technology   정보기술
# 3      CLRB          Healthcare   헬스케어
# 4     NYMTM         Real Estate    NaN
# ...     ...                 ...    ...
# 2738   EPSN              Energy    에너지
# 2739   SLRX          Healthcare   헬스케어
# 2740   CARE  Financial Services     금융
# 2741   CLPS          Technology   정보기술
# 2742    IEP              Energy    에너지
#
# [2743 rows x 3 columns]

# %% [markdown]
# # 경제지표 processing

# %%
# Fred 에서 수집한 4가지 경제지표 데이터 load
bei = pd.read_csv('C:/Users/Administrator/Desktop/비어플_NH/data/BEI.csv')
interest = pd.read_csv('C:/Users/Administrator/Desktop/비어플_NH/data/interest.csv')
crude = pd.read_csv('C:/Users/Administrator/Desktop/비어플_NH/data/crude.csv')
bond = pd.read_csv('C:/Users/Administrator/Desktop/비어플_NH/data/bond.csv')

# %%
bei.columns = ['Date', 'bei']
interest.columns = ['Date', 'interest']
crude.columns = ['Date', 'crude']
bond.columns = ['Date', 'bond']

# %%
#Date = pd.date_range(start="2023-01-03", end="2023-08-30").astype(str)
#D = pd.DataFrame()

#D['Date'] = Date
#D

eco = pd.merge(D, bei, how='left', on='Date')
eco = pd.merge(eco, interest, how='left', on = 'Date')
eco = pd.merge(eco, crude, how='left', on = 'Date')
eco = pd.merge(eco, bond, how='left', on = 'Date')

eco.replace('.', np.NaN, inplace = True)
eco = eco.astype({'bei': float})
eco = eco.astype({'interest': float})
eco = eco.astype({'crude': float})
eco = eco.astype({'bond': float})

eco = eco.fillna(method = 'pad') #결측치 바로 이전 행값으로 채우기
eco
# Out:
#            Date   bei  interest  crude  bond
# 0    2023-01-03  2.26     -0.61  76.87  4.70
# 1    2023-01-04  2.22     -0.67  72.82  4.62
# 2    2023-01-05  2.22     -0.74  73.61  4.58
# 3    2023-01-06  2.21     -0.69  73.77  4.47
# 4    2023-01-07  2.21     -0.69  73.77  4.47
# ..          ...   ...       ...    ...   ...
# 235  2023-08-26  2.33     -0.78  80.47  3.90
# 236  2023-08-27  2.33     -0.78  80.47  3.90
# 237  2023-08-28  2.30     -0.78  80.65  3.86
# 238  2023-08-29  2.29     -0.75  81.14  3.87
# 239  2023-08-30  2.26     -0.78  81.64  3.80
#
# [240 rows x 5 columns]

# %% [markdown]
# # 누적 수익률 데이터 생성

# %%
kr = kr_price.set_index('Date')
ov = ov_price.set_index('Date')

# %%
kr_per = kr.pct_change()
ov_per = ov.pct_change()

kr_cum = (1+kr_per).cumprod()-1
ov_cum = (1+ov_per).cumprod()-1

# %%
#월말 기준 누적 수익률
kr_mon = kr_cum.loc[['2023-01-31','2023-02-28','2023-03-31','2023-04-30','2023-05-31','2023-06-30','2023-07-31','2023-08-30'],:].T
ov_mon = ov_cum.loc[['2023-01-31','2023-02-28','2023-03-31','2023-04-30','2023-05-31','2023-06-30','2023-07-31','2023-08-30'],:].T

# %%
kr_mon['종목'] = kr_mon.index
ov_mon['종목'] = ov_mon.index

kr_mon.reset_index(drop = True, inplace = True)
ov_mon.reset_index(drop = True, inplace = True)

kr_mon.columns = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','종목']
ov_mon.columns = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','종목']
kr_mon = kr_mon[['종목','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug']]
ov_mon = ov_mon[['종목','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug']]

# %%
import matplotlib.pyplot as plt
plt.hist(kr_mon['Jan'], histtype ='bar', rwidth = .9, bins = 100)
plt.xlim([-0.5,0.5])
# Out:
# (-0.5, 0.5)

# %%
plt.hist(kr_mon['Aug'], histtype ='bar', rwidth = .9, bins = 300)
plt.xlim([-0.5,0.5])
# Out:
# (-0.5, 0.5)

# %%
kr_mon['Jan_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Jan']]
kr_mon['Feb_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Mar']]
kr_mon['Mar_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Jan']]
kr_mon['Apr_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Apr']]
kr_mon['May_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['May']]
kr_mon['Jun_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Jun']]
kr_mon['Jul_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Jul']]
kr_mon['Aug_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon['Aug']]

ov_mon['Jan_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Jan']]
ov_mon['Feb_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Mar']]
ov_mon['Mar_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Jan']]
ov_mon['Apr_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Apr']]
ov_mon['May_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['May']]
ov_mon['Jun_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Jun']]
ov_mon['Jul_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Jul']]
ov_mon['Aug_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon['Aug']]

# %% [markdown]
# # 시가총액 Sector 별 상위 30 종목 데이터 생성

# %%
#시가총액 Sector 별 상위 30 종목 추출, 국내
krx = fdr.StockListing('krx-marcap')

krx['markap'] = krx.index
krx = krx.loc[:,['Name','markap']]
krx.columns = ['종목명','시가총액순위']
kr_mer = pd.merge(krx, kr_sec, how = 'left', on = '종목명')

# 중요 Sector 6개 선정
kr_sec_180 =  kr_mer.sort_values(by='시가총액순위', ascending = True).groupby('sector').head(40)
kr_sec_180 = kr_sec_180.loc[:,['종목명','sector']]
kr_sec_180 = kr_sec_180[kr_sec_180['sector'].isin(['산업재','정보기술','금융','헬스케어','소재','커뮤니케이션서비스'])]

# 가격데이터와 Sector 데이터에 동시에 존재하는 종목 추출
col_kr = kr.columns.to_list()
kr_list = kr_sec_180['종목명'].to_list()
col_kr_list_1 = [x for x in kr_list if x in col_kr]
kr_sec_180 = kr_sec_180[kr_sec_180['종목명'].isin(col_kr_list_1)]

kr_sec_180 = kr_sec_180.groupby('sector').head(30)
col_kr_list = kr_sec_180['종목명'].to_list()
#col_kr_list = [x for x in kr_list if x in col_kr]
kr_price_180 = kr[col_kr_list]

#시가총액 Sector 별 상위 30 종목 추출, 해외(NASDAQ)
nasd = fdr.StockListing('NASDAQ')

nasd['markap'] = nasd.index
nasd = nasd.loc[:,['Symbol','markap']]
nasd.columns = ['종목명','시가총액순위']
ov_mer = pd.merge(nasd, ov_sec, how = 'left', on = '종목명')

# Sector 없는 종목 삭제
ov_mer.dropna(axis = 0, inplace = True)

# 중요 Sector 6개 선정
ov_sec_180 =  ov_mer.sort_values(by='시가총액순위', ascending = True).groupby('sector').head(40)
ov_sec_180 = ov_sec_180.loc[:,['종목명','sector']]
ov_sec_180 = ov_sec_180[ov_sec_180['sector'].isin(['산업재','정보기술','금융','헬스케어','소재','커뮤니케이션서비스'])]

# 가격데이터와 Sector 데이터에 동시에 존재하는 종목 추출
col_ov = ov.columns.to_list()
ov_list = ov_sec_180['종목명'].to_list()
col_ov_list_1 = [x for x in ov_list if x in col_ov]
ov_sec_180 = ov_sec_180[ov_sec_180['종목명'].isin(col_ov_list_1)]

ov_sec_180 = ov_sec_180.groupby('sector').head(30)
col_ov_list = ov_sec_180['종목명'].to_list()
#col_kr_list = [x for x in kr_list if x in col_kr]
ov_price_180 = ov[col_ov_list]
# Out:
# 100%|██████████| 4128/4128 [00:08<00:00, 513.25it/s]

# %%
kr_per_180 = kr_price_180.pct_change()
ov_per_180 = ov_price_180.pct_change()

kr_cum_180 = (1+kr_per_180).cumprod()-1
ov_cum_180 = (1+ov_per_180).cumprod()-1

#월말 기준 누적 수익률
kr_mon_180 = kr_cum_180.loc[['2023-01-31','2023-02-28','2023-03-31','2023-04-30','2023-05-31','2023-06-30','2023-07-31','2023-08-30'],:].T
ov_mon_180 = ov_cum_180.loc[['2023-01-31','2023-02-28','2023-03-31','2023-04-30','2023-05-31','2023-06-30','2023-07-31','2023-08-30'],:].T

kr_mon_180['종목'] = kr_mon_180.index
ov_mon_180['종목'] = ov_mon_180.index

kr_mon_180.reset_index(drop = True, inplace = True)
ov_mon_180.reset_index(drop = True, inplace = True)

kr_mon_180.columns = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','종목']
ov_mon_180.columns = ['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','종목']
kr_mon_180 = kr_mon_180[['종목','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug']]
ov_mon_180 = ov_mon_180[['종목','Jan','Feb','Mar','Apr','May','Jun','Jul','Aug']]

kr_mon_180['Jan_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Jan']]
kr_mon_180['Feb_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Mar']]
kr_mon_180['Mar_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Jan']]
kr_mon_180['Apr_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Apr']]
kr_mon_180['May_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['May']]
kr_mon_180['Jun_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Jun']]
kr_mon_180['Jul_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Jul']]
kr_mon_180['Aug_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in kr_mon_180['Aug']]

ov_mon_180['Jan_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Jan']]
ov_mon_180['Feb_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Mar']]
ov_mon_180['Mar_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Jan']]
ov_mon_180['Apr_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Apr']]
ov_mon_180['May_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['May']]
ov_mon_180['Jun_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Jun']]
ov_mon_180['Jul_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Jul']]
ov_mon_180['Aug_earning'] = ['High' if i > 0.2 else 'middle' if i > -0.2 else 'Low' for i in ov_mon_180['Aug']]

# %%
kr_mon.to_csv('kr_earning.csv', encoding='UTF-8-sig')
ov_mon.to_csv('ov_earning.csv', encoding='UTF-8-sig')

kr_sec.to_csv('kr_sec.csv', encoding='UTF-8-sig')
ov_sec.to_csv('ov_sec.csv', encoding='UTF-8-sig')

ov_price.to_csv('ov_price.csv', encoding='UTF-8-sig')
kr_price.to_csv('kr_price.csv', encoding='UTF-8-sig')

kr_mon_180.to_csv('kr_earning_180.csv', encoding='UTF-8-sig')
ov_mon_180.to_csv('ov_earning_180.csv', encoding='UTF-8-sig')

kr_sec_180.to_csv('kr_sec_180.csv', encoding='UTF-8-sig')
ov_sec_180.to_csv('ov_sec_180.csv', encoding='UTF-8-sig')

ov_price_180.to_csv('ov_price_180.csv', encoding='UTF-8-sig')
kr_price_180.to_csv('kr_price_180.csv', encoding='UTF-8-sig')

eco.to_csv('economics.csv', encoding='UTF-8-sig')
